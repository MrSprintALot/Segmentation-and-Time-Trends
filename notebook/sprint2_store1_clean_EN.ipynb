# %% [markdown]
# - Recommendations map segment → message, offer, channel, and timing based on insights.

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# This section was cleaned to remove reviewer notes and is now expressed in English.

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]],
]

for user in users:
    user[1] = user[1].strip().replace('_',' ').title()
    user[2] = int(user[2])
    
for user in users:
    print(user)
# Out:
# ['32415', 'Mike Reed', 32, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]]
# ['31980', 'Kate Morgan', 24, ['CLOTHES', 'BOOKS'], [439, 390]]
# ['32156', 'John Doe', 37, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]]
# ['32761', 'Samantha Smith', 29, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]]
# ['32984', 'David White', 41, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]]
# ['33001', 'Emily Brown', 26, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]]
# ['33767', 'Maria Garcia', 33, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]]
# ['33912', 'Jose Martinez', 22, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]]
# ['34009', 'Lisa Wilson', 35, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]]
# ['34278', 'James Lee', 28, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]]

# %% [markdown]
# # Paso 1
#
# - We audit dtypes, handle missing values/duplicates, and ensure consistent keys before analysis.

# %%
def clean_user(user_info, name_index, age_index): # define tu función aquí

    # Paso 1: elimina del nombre espacios iniciales y finales, así como guiones
    user_name_1 = user_info[name_index].strip().replace('_', ' ')

    # Paso 2: convierte la edad en entero
    user_age_1 = int(user_info[age_index])

    # Paso 3: separa el nombre y el apellido en una sublista
    user_name_1 = user_name_1.split()

    # Prepara la lista con la información completa del usuario
    # Reemplaza el nombre y la edad originales con los datos limpios
    user_info[name_index] = user_name_1
    user_info[age_index] = user_age_1

    return user_info

# Prueba la función
test_user = ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]]
name_index = 1
age_index = 2

print(clean_user(test_user, name_index, age_index)) # completa aquí el llamado de la función
# Out:
# ['32415', ['mike', 'reed'], 32, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]]

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# - We audit dtypes, handle missing values/duplicates, and ensure consistent keys before analysis.

# %% [markdown]
# # Paso 2
#
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %%
fav_categories = ['ELECTRONICS', 'SPORT', 'BOOKS']
fav_categories_low = []

for category in fav_categories: # creamos el bucle sobre la lista
    category_lower = category.lower() # transformamos a minusculas cada category
    fav_categories_low.append(category_lower) # agregamos valores actualizados a la lista

print(fav_categories_low)
# Out:
# ['electronics', 'sport', 'books']

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# # Paso 3
#
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]],
]

users_categories_low = []
for user in users:
    categories_low = []
    
    for category in user[3]: # escribe tu código aquí
        lowered_category = category.lower() # convertimos a minuscula
        categories_low.append(lowered_category)
        
    user.pop(3) # eliminamos la lista de categorias original
    user.insert(3, categories_low) # insertamos la lista en minuscula
    users_categories_low.append(user) # agregamos el user modificado a la lista

print(users_categories_low)
# Out:
# [['32415', ' mike_reed ', 32.0, ['electronics', 'sport', 'books'], [894, 213, 173]], ['31980', 'kate morgan', 24.0, ['clothes', 'books'], [439, 390]], ['32156', ' john doe ', 37.0, ['electronics', 'home', 'food'], [459, 120, 99]], ['32761', 'SAMANTHA SMITH', 29.0, ['clothes', 'electronics', 'beauty'], [299, 679, 85]], ['32984', 'David White', 41.0, ['books', 'home', 'sport'], [234, 329, 243]], ['33001', 'emily brown', 26.0, ['beauty', 'home', 'food'], [213, 659, 79]], ['33767', ' Maria Garcia', 33.0, ['clothes', 'food', 'beauty'], [499, 189, 63]], ['33912', 'JOSE MARTINEZ', 22.0, ['sport', 'electronics', 'home'], [259, 549, 109]], ['34009', 'lisa wilson ', 35.0, ['home', 'books', 'clothes'], [329, 189, 329]], ['34278', 'James Lee', 28.0, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Excelente uso de un for anidado dentro de otro for, de tal manera que puedas iterar sobre las iteraciones de otro for.

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# # Paso 4
#
# - We audit dtypes, handle missing values/duplicates, and ensure consistent keys before analysis.

# %%
def clean_user(user_info, name_index, age_index, cat_index):
    # convertimos el nombre a minúsculas, eliminamos espacios y reemplazamos guiones bajos
    user_name_1 = user_info[name_index].lower().strip().replace('_', ' ')
    
    # convertimos la edad en entero
    user_age_1 = int(user_info[age_index])
    
    # separamos el nombre y el apellido en una sublista
    user_name_1 = user_name_1.split()
    
    # convertimos las categorías a minúsculas
    categories_low = [category.lower() for category in user_info[cat_index]]
    
    # Reemplazamos el nombre, edad y categorías en la lista original
    user_info[name_index] = user_name_1
    user_info[age_index] = user_age_1
    user_info[cat_index] = categories_low
    
    return user_info


users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]],
]

name_index = 1
age_index = 2
cat_index = 3
users_cleaned = []     
      
for user in users:
  user_cleaned = clean_user(user, name_index, age_index, cat_index)
  users_cleaned.append(user_cleaned) 

print(users_cleaned)
# Out:
# [['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]], ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]], ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]], ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]], ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]], ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]], ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]], ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]], ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]], ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Excelente trabajo agregando el parametro del indice de categorias!
# </div>

# %% [markdown]
# - We audit dtypes, handle missing values/duplicates, and ensure consistent keys before analysis.

# %% [markdown]
# # Paso 5
#
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %%
users = [['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]],
         ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]],
         ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]],
         ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]],
         ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]],
         ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]],
         ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]],
         ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]],
         ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]],
         ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]

revenue = 0

for user in users:
    spendings_list = user[4] # extraemos lista de gastos de usuario
    total_spendings = sum(spendings_list) # sumamos los valores de la lista de gastos
    revenue += total_spendings # actualizamos los ingresos totales

print(revenue)
# Out:
# 9189

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Gran trabajo agregando los sumado por cada usuario. Excelente uso de +=

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# # Paso 6
#
# - Objective: personalize campaigns by understanding segments and time dynamics.

# %%
from random import randint

total_amount_spent = 1280
target_amount = 1500

while total_amount_spent < target_amount:
	new_purchase = randint(30, 80) # generamos un número aleatorio de 30 a 80
	total_amount_spent += new_purchase # sumamos la nueva compra al total

print(total_amount_spent)
# Out:
# 1530

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Muy buen trabajo! Excelente trabajo con el uso del while y de +=.

# %% [markdown]
# - Objective: personalize campaigns by understanding segments and time dynamics.

# %% [markdown]
# # Paso 7
#
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %%
users = [['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]],
         ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]],
         ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]],
         ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]],
         ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]],
         ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]],
         ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]],
         ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]],
         ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]],
         ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]


for user in users:
    if user[2] < 30: # verificamos si la edad es menor a 30
        print(user[1][0], user[1][1]) # imprimimos el nombre completo
# Out:
# kate morgan
# samantha smith
# emily brown
# jose martinez
# james lee

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Muy buen trabajo con el uso del ciclo for y del condicional if.
#
# </div>

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# # Paso 8
#
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %%
users = [['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]],
         ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]],
         ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]],
         ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]],
         ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]],
         ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]],
         ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]],
         ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]],
         ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]],
         ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]

valid_users = []

for user in users:
    spendings_list = user[4] # extraemos la lista de gastos del usuario 
    total_spendings = sum(spendings_list) # sumamos los valores de la lista de gastos
    
    if user[2] < 30 and total_spendings > 1000: # filtramos por condicional
        valid_users.append(user[1][0] + " " + user[1][1])
print(valid_users)
# Out:
# ['samantha smith', 'james lee']

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# Muy buen trabajo con el uso del ciclo for y del condicional if. Solamente verifica que todos cumplen la condicion de gasto mayor a 1000
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Gran trabajo con el ajuste!

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# # Paso 9
#
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %%
users = [['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]],
         ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]],
         ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]],
         ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]],
         ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]],
         ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]],
         ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]],
         ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]],
         ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]],
         ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]

for user in users:
    if 'clothes' in user[3]: # verificamos si clothes esta en la lita de categorias
        firstname = user[1][0] # obtenemos el primer nombre
        age = user[2] # obtenemos la edad
        print(firstname, ',', age)
# Out:
# kate , 24
# samantha , 29
# maria , 33
# lisa , 35
# james , 28

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Muy buen trabajo con el uso del ciclo for y del condicional if.
#
# </div>

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# # Paso 10
#
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %%
def get_client_by_cat(users, id_index, name_index, age_index, category_index, amounts_index, filter_category): # definimos la funcion
    result = []
    for user in users: # recorremos la lista de usuarios
        if filter_category in user[category_index]: # verificamos si la categoria que buscamos esta en las compras del usuario
            total_spent = sum(user[amounts_index]) # calcualmos el total gastado
            result.append([user[id_index], user[name_index], user[age_index], total_spent]) # agregamos los datos de usuario a la lista
    return result

# La lista de usuarios
users = [
    ['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]],
    ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]],
    ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]],
    ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]],
    ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]],
    ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]],
    ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]],
    ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]],
    ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]],
    ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]
]

# Llama a la función con la categoría 'home'
result = get_client_by_cat(users, 0, 1 , 2, 3 , 4, 'home')

# Muestra en pantalla la lista que resulta
print(result)
# Out:
# [['32156', ['john', 'doe'], 37, 678], ['32984', ['david', 'white'], 41, 806], ['33001', ['emily', 'brown'], 26, 951], ['33912', ['jose', 'martinez'], 22, 917], ['34009', ['lisa', 'wilson'], 35, 847]]

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Excelente trabajo, agregaste todas las herramientas para completar este ejercicio. Filtraste por catergoria, obtienes el gasto total y muestras las variables deseadas.

# %% [markdown]
# This section describes the step and the rationale behind the analysis in clear, concise English.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# Sigue con el excelente trabajo!
